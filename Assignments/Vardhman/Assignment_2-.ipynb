# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the dataset

# %%
data=pd.read_csv('/content/gdrive/My Drive/Churn_Modelling.csv')
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# Univariate Data Visualization

# %%
sns.boxplot(data["CreditScore"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxenplot(data.CreditScore)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data["Age"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data["Balance"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxenplot(data.Balance)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data.EstimatedSalary)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Bi-variate Data Visualization

# %%
sns.scatterplot(data.Age,data.Balance)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(data.Age,data.EstimatedSalary)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(data.Age,data.CreditScore)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(12,8))
sns.swarmplot(data.Geography,data.EstimatedSalary,data=data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 43.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 5.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Multi-variate Data Visualization

# %%
sns.catplot(x="NumOfProducts",y="Balance",data=data,hue="Geography",kind='box')

# %%
sns.catplot(x="NumOfProducts",y="Age",data=data,hue="Geography",kind='box')

# %%
sns.violinplot(x="IsActiveMember",y="NumOfProducts",data=data,hue="Geography")

# %%
sns.pairplot(data=data,hue="Exited",kind='hist')

# %%
sns.boxplot(x="Exited",y="Age",data=data,hue="Gender")

# %% [markdown]
# Perform descriptive statistics on the dataset

# %%
data.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %% [markdown]
# Handle the Missing values

# %%
data.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
data["Gender"].value_counts()
data["Gender"].replace({"Male":1,"Female":0},inplace=True)
data["Surname"]=data["Surname"].astype(str)

# %%
data["Geography"].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
data["Geography"].str.strip()
data["Surname"].str.strip()
# Out:
# 0        Hargrave
# 1            Hill
# 2            Onio
# 3            Boni
# 4        Mitchell
#           ...
# 9995     Obijiaku
# 9996    Johnstone
# 9997          Liu
# 9998    Sabbatini
# 9999       Walker
# Name: Surname, Length: 10000, dtype: object

# %%
data.hist(figsize=(20,12),legend=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f98ae007350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98adfa6590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98adf59fd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f98adf87190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98ae040890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98adef4b90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f98adeb70d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98ade6f5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98ade78a50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f98ade3c090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98add9e510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f98add54a10>]],
#       dtype=object)

# %%
data.drop(columns=["RowNumber","CustomerId"],inplace=True)
data.head()
# Out:
#     Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0  Hargrave          619    France       0   42       2       0.00
# 1      Hill          608     Spain       0   41       1   83807.86
# 2      Onio          502    France       0   42       8  159660.80
# 3      Boni          699    France       0   39       1       0.00
# 4  Mitchell          850     Spain       0   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0

# %%
data["Surname"].value_counts()
# Out:
# Smith       32
# Scott       29
# Martin      29
# Walker      28
# Brown       26
#             ..
# Izmailov     1
# Bold         1
# Bonham       1
# Poninski     1
# Burbidge     1
# Name: Surname, Length: 2932, dtype: int64

# %%
data.duplicated().value_counts()
# Out:
# False    10000
# dtype: int64

# %%
plt.figure(figsize=(15,9))
sns.heatmap(data.corr(),annot=True)

# %% [markdown]
# Find the outliers and replace the outliers

# %%
q1=data["Age"].quantile(0.25)
q3=data["Age"].quantile(0.75)
iq=q3-q1
data=data[~((data["Age"]<(q1-1.5*iq))|(data["Age"]>(q3+1.5*iq)))]

# %%
q1=data["CreditScore"].quantile(0.25)
q3=data["CreditScore"].quantile(0.75)
iq=q3-q1
data=data[~((data["CreditScore"]<(q1-1.5*iq))|(data["CreditScore"]>(q3+1.5*iq)))]

# %%
data[(data["Age"]<(data["Age"].mean()-3*data["Age"].std()))|(data["Age"]>(data["Age"].mean()+3*data["Age"].std()))]
# Out:
# Empty DataFrame
# Columns: [Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %% [markdown]
# Check for Categorical columns and perform encoding

# %%
geo=pd.get_dummies(data["Geography"],drop_first=True)
data1=pd.concat([data,geo],axis=1)
data1
# Out:
#         Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0      Hargrave          619    France       0   42       2       0.00
# 1          Hill          608     Spain       0   41       1   83807.86
# 2          Onio          502    France       0   42       8  159660.80
# 3          Boni          699    France       0   39       1       0.00
# 4      Mitchell          850     Spain       0   43       2  125510.82
# ...         ...          ...       ...     ...  ...     ...        ...
# 9995   Obijiaku          771    France       1   39       5       0.00
# 9996  Johnstone          516    France       1   35      10   57369.61
# 9997        Liu          709    France       0   36       7       0.00
# 9998  Sabbatini          772   Germany       1   42       3   75075.31
# 9999     Walker          792    France       0   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0                 1          1               1        101348.88       1
# 1                 1          0               1        112542.58       0
# 2                 3          1               0        113931.57       1
# 3                 2          0               0         93826.63       0
# 4                 1          1               1         79084.10       0
# ...             ...        ...             ...              ...     ...
# 9995              2          1               0         96270.64       0
# 9996              1          1               1        101699.77       0
# 9997              1          0               1         42085.58       1
# 9998              2          1               0         92888.52       1
# 9999              1          1               0         38190.78       0
#
#       Germany  Spain
# 0           0      0
# 1           0      1
# 2           0      0
# 3           0      0
# 4           0      1
# ...       ...    ...
# 9995        0      0
# 9996        0      0
# 9997        0      0
# 9998        1      0
# 9999        0      0
#
# [9627 rows x 14 columns]

# %% [markdown]
# Split the data into dependent and independent variables

# %%
x=data1.drop(columns=["Geography","Exited"])
y=data["Exited"]
x.head()
# Out:
#     Surname  CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0  Hargrave          619       0   42       2       0.00              1
# 1      Hill          608       0   41       1   83807.86              1
# 2      Onio          502       0   42       8  159660.80              3
# 3      Boni          699       0   39       1       0.00              2
# 4  Mitchell          850       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Germany  Spain
# 0          1               1        101348.88        0      0
# 1          0               1        112542.58        0      1
# 2          1               0        113931.57        0      0
# 3          0               0         93826.63        0      0
# 4          1               1         79084.10        0      1

# %% [markdown]
# Split the data into training and testing

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
x_train.shape,x_test.shape
# Out:
# ((7701, 12), (1926, 12))
